# %%
import pandas as pd
import numpy as np
import random
import csv
df = pd.DataFrame.from_csv('C:/Users/luca.chech.16/Desktop/jupyter exp/all_images.csv')
#f = pd.DataFrame.from_csv('C:/Users/nilli lab/Desktop/Luca Exp/jupyter exp/all_images.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load)}

# DEFINING TARGET-PRESENT TRIALS
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for each_1 in categories:
    for load in p_load:
        i = 0
        while True:
            trial = np.random.choice(lista, 1, replace= False)
            a = str(trial)
            a =a[2:-2]
            if each_1 in possible_images_dict[a] and load in possible_images_dict[a] and a not in intermediate and a not in target_present:
                intermediate.append(a)
            if len(intermediate) == 10:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(each_1)
                intermediate = []
                break

print len(target_present)
#--------------------
target_present_dict = {key:possible_images_dict[key] for key in target_present}
target_absent_dict = dict(possible_images_dict)
for each in target_present:
    if each in target_absent_dict:
        del target_absent_dict[each]
exp_dict = dict(target_present_dict)
exp_dict.update(target_absent_dict)
print len(target_present_dict)
print len(target_absent_dict)
print len(exp_dict)


for each in target_present_dict:
    target_present_dict[each].append('Target Present')
for each in target_absent_dict:
    absent_question = []
    for ogni in categories:
        if ogni not in target_absent_dict[each]:
            absent_question.append(ogni)
    absent_question = np.random.choice(absent_question, 1, replace= False)
    absent_question = str(absent_question)
    absent_question = absent_question[2:-2]
    #print absent_question
    #print type(absent_question)
    target_absent_dict[each].append(absent_question)
    target_absent_dict[each].append('Target Absent')
    
# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level, present_absent):
    intermediate = []
    for element in lista:
        if load_level in possible_images_dict[element] and present_absent in possible_images_dict[element]:
            intermediate.append(element)  
    intermediate = np.random.choice(intermediate, 20, replace= False)
    for each in intermediate:
        each = str(each)
        critical_trials.append(each)
critical_trial('low','Target Present')
critical_trial('high','Target Present')
critical_trial('low','Target Absent')
critical_trial('high','Target Absent')

for each in critical_trials:
    exp_dict[each].append('Critical')
for each in exp_dict:
    if 'Critical' not in exp_dict[each]:
        exp_dict[each].append('Normal')
#-----------------------

df = pd.DataFrame.from_dict(exp_dict)
df= df.T
#df.reset_index(inplace = 'True')
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','question','present_absent','trial_type']
df.TS = df.TS.astype('float')

df.to_csv('randomization.csv')
#df.groupby(['trial_type','present_absent', 'Load']).TS.count()
#df.groupby(['trial_type', 'Load']).TS.count()
df.groupby(['trial_type', 'Load']).TS.mean()
df.head()
# Out:
# 240
# 240
# 240
# 480
#                       Cat.1     Cat.2    Cat.3 Cat.4 Cat.5         TS  Load  \
# 2008_000015.jpg      bottle       NaN      NaN   NaN   NaN  31.539720  high
# 2008_000023.jpg   tvmonitor    bottle   person   NaN   NaN  35.932514  high
# 2008_000033.jpg   aeroplane       NaN      NaN   NaN   NaN  16.997423   low
# 2008_000036.jpg      person   bicycle     boat   NaN   NaN  33.118834  high
# 2008_000037.jpg   aeroplane       NaN      NaN   NaN   NaN  12.091823   low
#
#                    question  present_absent trial_type
# 2008_000015.jpg      bottle  Target Present   Critical
# 2008_000023.jpg      bottle  Target Present     Normal
# 2008_000033.jpg   aeroplane  Target Present   Critical
# 2008_000036.jpg       horse   Target Absent     Normal
# 2008_000037.jpg       horse   Target Absent     Normal

# %%
sound_onset = [50] * 4 + [100] * 4 + [150] * 4 + [200] * 4 + [250] * 4
sound_Hz = [500] * 5 + [1000] * 5 + [1500] * 5 + [2000] * 5
print sound_Hz, len(sound_Hz)
print sound_onset, len(sound_onset)
# Out:
# [500, 500, 500, 500, 500, 1000, 1000, 1000, 1000, 1000, 1500, 1500, 1500, 1500, 1500, 2000, 2000, 2000, 2000, 2000] 20
# [50, 50, 50, 50, 100, 100, 100, 100, 150, 150, 150, 150, 200, 200, 200, 200, 250, 250, 250, 250] 20

# %%
exp_dict
# Out:
# {'2008_000015.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.539720000815944,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Critical'],
#  '2008_000023.jpg': [' tvmonitor',
#   ' bottle',
#   ' person',
#   nan,
#   nan,
#   35.932513711272492,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_000033.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.997423338421303,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Critical'],
#  '2008_000036.jpg': [' person',
#   ' bicycle',
#   ' boat',
#   nan,
#   nan,
#   33.11883423930427,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_000037.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   12.091823003636206,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_000064.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.799443519388333,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2008_000076.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.993717043020187,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_000089.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.267557827613276,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_000112.jpg': [' bottle',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   21.259829756421425,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_000142.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   19.226645392830168,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_000177.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.396955524186414,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_000185.jpg': [' person',
#   ' car',
#   nan,
#   nan,
#   nan,
#   17.007637825531805,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_000189.jpg': [' person',
#   ' car',
#   nan,
#   nan,
#   nan,
#   18.390878339274188,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_000192.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.176311484999022,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_000196.jpg': [' pottedplant',
#   ' bicycle',
#   ' bottle',
#   ' cat',
#   nan,
#   35.353784429943062,
#   'high',
#   ' cat',
#   'Target Present',
#   'Critical'],
#  '2008_000202.jpg': [' person',
#   ' chair',
#   ' bottle',
#   ' tvmonitor',
#   nan,
#   34.633056090581924,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_000226.jpg': [' person',
#   ' car',
#   nan,
#   nan,
#   nan,
#   38.328936159203323,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_000251.jpg': [' car',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   35.872179407942049,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_000270.jpg': [' person',
#   ' dog',
#   ' sofa',
#   nan,
#   nan,
#   29.935618386927253,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_000274.jpg': [' pottedplant',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   32.054269676274835,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_000287.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.549656454901235,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_000359.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.57495438113213,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_000398.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   20.423795473772003,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_000399.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.515948763562573,
#   'low',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_000421.jpg': [' person',
#   ' bottle',
#   ' sofa',
#   nan,
#   nan,
#   28.876320236016397,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_000501.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.29867809750948,
#   'low',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_000533.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.809456573367793,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2008_000536.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.530474638100298,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_000564.jpg': [' pottedplant',
#   ' person',
#   nan,
#   nan,
#   nan,
#   31.19071287356914,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_000619.jpg': [' car',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   33.462184790468179,
#   'high',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_000646.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.395747249343186,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_000666.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.884234980553654,
#   'low',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_000704.jpg': [' sofa',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   34.561608236038907,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_000721.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.283594834913739,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Critical'],
#  '2008_000734.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   20.185339334432726,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_000777.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.325858104825315,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_000785.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.75643370350906,
#   'low',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_000798.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.594597886254714,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_000833.jpg': [' car',
#   ' boat',
#   ' person',
#   nan,
#   nan,
#   32.759267418843763,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_000839.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.456101242175052,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_000860.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.401451132133516,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_001013.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   30.12491788069191,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_001040.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.210043703583391,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2008_001167.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   30.274651313457607,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2008_001182.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   32.236048221294716,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_001188.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.856435481112946,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_001210.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.246976174425782,
#   'high',
#   ' cat',
#   'Target Present',
#   'Critical'],
#  '2008_001238.jpg': [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   21.001227278103954,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Critical'],
#  '2008_001283.jpg': [' pottedplant',
#   ' person',
#   ' bird',
#   nan,
#   nan,
#   32.325935045893075,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_001312.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   31.293565916638769,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_001318.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.758645547697638,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_001333.jpg': [' sofa',
#   ' chair',
#   ' bottle',
#   ' person',
#   nan,
#   29.051766794986211,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_001338.jpg': [' pottedplant',
#   ' person',
#   ' chair',
#   nan,
#   nan,
#   30.397038981662675,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_001439.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.877131641055023,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_001464.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.756714401720171,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_001503.jpg': [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   14.964343777361664,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_001549.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.319559259243235,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_001620.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   37.950629666907169,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2008_001636.jpg': [' person',
#   ' chair',
#   ' bottle',
#   nan,
#   nan,
#   33.954499092122084,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_001673.jpg': [' person',
#   ' chair',
#   ' bird',
#   nan,
#   nan,
#   29.630121226979949,
#   'high',
#   ' bird',
#   'Target Present',
#   'Critical'],
#  '2008_001694.jpg': [' pottedplant',
#   ' sofa',
#   ' chair',
#   nan,
#   nan,
#   18.511887801846186,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_001714.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.516930411914359,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Critical'],
#  '2008_001774.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.239448220226901,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2008_001782.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.246142987245754,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_001783.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.628383047479893,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_001911.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.111517556329524,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2008_002079.jpg': [' person',
#   ' bottle',
#   ' diningtable',
#   nan,
#   nan,
#   33.022066804988405,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_002084.jpg': [' pottedplant',
#   ' person',
#   ' dog',
#   nan,
#   nan,
#   30.007374331932049,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_002116.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   20.166020393270408,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_002119.jpg': [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' tvmonitor',
#   nan,
#   29.464580095555625,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_002131.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   30.278807232868253,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2008_002153.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.839786502680184,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_002199.jpg': [' car',
#   ' bottle',
#   ' person',
#   nan,
#   nan,
#   36.80648001944207,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_002350.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.814920313574749,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_002372.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.593336877343006,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Critical'],
#  '2008_002379.jpg': [' pottedplant',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   17.13857605003491,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_002410.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.15324251930145,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_002414.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.063680022466887,
#   'low',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2008_002442.jpg': [' person',
#   ' chair',
#   ' dog',
#   ' car',
#   nan,
#   19.939826301105867,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_002487.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.524302386897595,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_002504.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.470663952413528,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Critical'],
#  '2008_002666.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   20.789724110777932,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_002672.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.39404844580157,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_002704.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.439939384573201,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_002773.jpg': [' aeroplane',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   29.287349444649571,
#   'high',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_002835.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   31.842660584206165,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2008_002866.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   18.608778484059602,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Critical'],
#  '2008_002899.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.127469618562607,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_002966.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   31.413857547274947,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_003003.jpg': [' pottedplant',
#   ' tvmonitor',
#   nan,
#   nan,
#   nan,
#   20.933138197544839,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_003048.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.818927561072034,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_003061.jpg': [' car',
#   ' person',
#   nan,
#   nan,
#   nan,
#   29.7634843327506,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_003079.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   29.5321159816048,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_003104.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   9.8922186856238596,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_003120.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.512779024532247,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_003170.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.167558060312739,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_003180.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.537857125660089,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_003187.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.929957414682665,
#   'high',
#   ' sofa',
#   'Target Absent',
#   'Critical'],
#  '2008_003202.jpg': [' person',
#   ' tvmonitor',
#   ' car',
#   nan,
#   nan,
#   33.327883020630949,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_003203.jpg': [' pottedplant',
#   ' person',
#   nan,
#   nan,
#   nan,
#   20.515117634611254,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_003369.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.731962722166625,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2008_003378.jpg': [' car',
#   ' chair',
#   ' bicycle',
#   nan,
#   nan,
#   29.730810134820999,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_003380.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.989811995987314,
#   'high',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_003407.jpg': [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   34.858672303722905,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Critical'],
#  '2008_003461.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.927210340008561,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2008_003469.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.869285058966398,
#   'high',
#   ' car',
#   'Target Absent',
#   'Critical'],
#  '2008_003575.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   31.07062434195711,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2008_003587.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   19.793376112600363,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Critical'],
#  '2008_003680.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.997126181841569,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_003701.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.9571992215138,
#   'high',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_003766.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.24791995253582,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_003802.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.835460161890751,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_003805.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   29.875362071673013,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_003838.jpg': [' pottedplant',
#   ' chair',
#   ' dog',
#   nan,
#   nan,
#   17.398570575693821,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_003846.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.100322166714271,
#   'low',
#   ' car',
#   'Target Present',
#   'Critical'],
#  '2008_003852.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.163024969077554,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_003868.jpg': [' car',
#   ' person',
#   nan,
#   nan,
#   nan,
#   21.008579726600527,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_003921.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.029907280243368,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_003989.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.718847130103551,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2008_003995.jpg': [' tvmonitor',
#   ' person',
#   nan,
#   nan,
#   nan,
#   37.099471650809882,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_004042.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.397027824172856,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Critical'],
#  '2008_004100.jpg': [' car',
#   ' aeroplane',
#   ' person',
#   nan,
#   nan,
#   31.81214007053698,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_004142.jpg': [' person',
#   ' bicycle',
#   ' car',
#   nan,
#   nan,
#   29.732999273893491,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_004171.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.584162567185079,
#   'low',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2008_004175.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.095615762685927,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Critical'],
#  '2008_004269.jpg': [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   20.983298059388602,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_004270.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   19.244035875135978,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_004317.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   12.767746748489099,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_004412.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.413253715842107,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_004418.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   31.129492238094699,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_004459.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   31.124437166631626,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_004487.jpg': [' chair',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   35.925064893420085,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_004490.jpg': [' chair',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   16.578513977418865,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_004504.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.389814839494647,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_004564.jpg': [' person',
#   ' chair',
#   ' bottle',
#   ' diningtable',
#   nan,
#   28.719634584894571,
#   'high',
#   ' car',
#   'Target Absent',
#   'Critical'],
#  '2008_004568.jpg': [' person',
#   ' motorbike',
#   nan,
#   nan,
#   nan,
#   28.69888395168325,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_004584.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.466989220087964,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_004607.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.465741194973702,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Critical'],
#  '2008_004614.jpg': [' car',
#   ' bus',
#   ' person',
#   nan,
#   nan,
#   31.30513576919045,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2008_004615.jpg': [' pottedplant',
#   ' motorbike',
#   nan,
#   nan,
#   nan,
#   29.797419521088532,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_004619.jpg': [' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   nan,
#   nan,
#   32.058602979450178,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_004624.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.879634097368903,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_004646.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   32.014973550332165,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2008_004690.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.51535276170641,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_004814.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   19.869099247411821,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_004868.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   21.124230188956968,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_004907.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.580374337830555,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2008_004911.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.13897580401844,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_004933.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.895382180973067,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Critical'],
#  '2008_004984.jpg': [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   29.874415536174077,
#   'high',
#   ' person',
#   'Target Present',
#   'Critical'],
#  '2008_005001.jpg': [' pottedplant',
#   ' person',
#   nan,
#   nan,
#   nan,
#   34.943837141944897,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_005167.jpg': [' chair',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   15.545646286464276,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_005168.jpg': [' bus',
#   ' horse',
#   ' person',
#   nan,
#   nan,
#   30.792015071052184,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_005178.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   29.073434519731283,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_005396.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.607271453978441,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_005443.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.397289120778062,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2008_005444.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   14.904890287664626,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_005456.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.741125744496948,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_005490.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   13.414126280812802,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_005502.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.352406826905145,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2008_005504.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.830977256064813,
#   'high',
#   ' boat',
#   'Target Present',
#   'Critical'],
#  '2008_005519.jpg': [' pottedplant',
#   ' person',
#   ' chair',
#   ' diningtable',
#   nan,
#   31.520687613930374,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_005522.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.649920824350549,
#   'low',
#   ' person',
#   'Target Absent',
#   'Critical'],
#  '2008_005600.jpg': [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   30.226516379371251,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Critical'],
#  '2008_005702.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.28123750737463,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_005742.jpg': [' person',
#   ' train',
#   nan,
#   nan,
#   nan,
#   33.626640847537772,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_005750.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.201869461183065,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2008_005818.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.084159041893106,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Critical'],
#  '2008_005845.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.961816980758506,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2008_005853.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.373574356319935,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_005867.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   31.118687546941533,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_005869.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   17.242843490790587,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_005923.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   32.574931860447123,
#   'high',
#   ' boat',
#   'Target Present',
#   'Critical'],
#  '2008_006071.jpg': [' person',
#   ' dog',
#   ' car',
#   nan,
#   nan,
#   30.544723827741628,
#   'high',
#   ' car',
#   'Target Present',
#   'Critical'],
#  '2008_006072.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.259900940752694,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_006092.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.488603700645108,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_006119.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.029082262758406,
#   'low',
#   ' dog',
#   'Target Present',
#   'Critical'],
#  '2008_006121.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   30.384187271419634,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_006166.jpg': [' chair',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   29.625143727429808,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_006216.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   31.885877800404149,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_006276.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   12.390229780337766,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_006295.jpg': [' pottedplant',
#   ' tvmonitor',
#   ' diningtable',
#   ' bottle',
#   ' person',
#   33.940134374118173,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2008_006303.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.723636647719449,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Critical'],
#  '2008_006394.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.174269602228826,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_006461.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.182430259996877,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_006470.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.005917005737068,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2008_006481.jpg': [' bird',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   29.314233597971626,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_006546.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.671797488074596,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2008_006703.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.885436604139475,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_006784.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.055909373433501,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_006810.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.343832930042264,
#   'low',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2008_006837.jpg': [' chair',
#   ' dog',
#   ' diningtable',
#   nan,
#   nan,
#   18.206263900870965,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2008_006844.jpg': [' person',
#   ' dog',
#   ' car',
#   nan,
#   nan,
#   33.09488500291814,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_006863.jpg': [' person',
#   ' chair',
#   ' cat',
#   nan,
#   nan,
#   30.878848142402841,
#   'high',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_006912.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   28.936239221739456,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_006921.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.414503851226357,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_007028.jpg': [' person',
#   ' chair',
#   ' dog',
#   nan,
#   nan,
#   21.14335917098645,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_007043.jpg': [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   33.279582355794268,
#   'high',
#   ' car',
#   'Target Absent',
#   'Critical'],
#  '2008_007057.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   40.773121275105424,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2008_007151.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.683464699500671,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_007250.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.892125506726913,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_007281.jpg': [' sofa',
#   ' person',
#   ' bottle',
#   ' pottedplant',
#   ' tvmonitor',
#   36.889585254962064,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2008_007314.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.655346640693391,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2008_007388.jpg': [' pottedplant',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   28.766357844509439,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_007511.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.416096677014028,
#   'low',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_007567.jpg': [' tvmonitor',
#   ' dog',
#   ' bottle',
#   ' person',
#   nan,
#   29.293240865689178,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_007613.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.072553019018567,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_007664.jpg': [' diningtable',
#   ' person',
#   ' chair',
#   ' dog',
#   ' bottle',
#   36.040121428269742,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Critical'],
#  '2008_007704.jpg': [' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   nan,
#   20.038119878562025,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2008_007710.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   20.632739448523342,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_007733.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.585259952682449,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_007816.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.019476152805421,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_007913.jpg': [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   32.265109082996503,
#   'high',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2008_007923.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   19.05734476753717,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Critical'],
#  '2008_007970.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.073041628958684,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2008_007973.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.179050633756766,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_008029.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   31.119805313465481,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_008080.jpg': [' pottedplant',
#   ' bus',
#   ' bicycle',
#   nan,
#   nan,
#   33.240418838308358,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2008_008083.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   18.642450428633328,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2008_008203.jpg': [' pottedplant',
#   ' train',
#   nan,
#   nan,
#   nan,
#   29.327817397314352,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_008211.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.137938669726722,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2008_008229.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   33.702921971939176,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_008272.jpg': [' person',
#   ' diningtable',
#   ' sofa',
#   nan,
#   nan,
#   31.406664786149612,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2008_008341.jpg': [' pottedplant',
#   ' person',
#   nan,
#   nan,
#   nan,
#   30.931174236272426,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2008_008368.jpg': [' person',
#   ' bicycle',
#   ' car',
#   nan,
#   nan,
#   31.810247903263157,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Critical'],
#  '2008_008490.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.181410135127006,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2008_008533.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.20795639634078,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2008_008554.jpg': [' sofa',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   28.842949102710204,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2008_008607.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.020689907436754,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2008_008628.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.980311145262871,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2008_008681.jpg': [' car',
#   ' train',
#   nan,
#   nan,
#   nan,
#   30.208842852237311,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2008_008701.jpg': [' bus',
#   ' car',
#   ' person',
#   nan,
#   nan,
#   34.377160047252133,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2008_008770.jpg': [' pottedplant',
#   ' train',
#   nan,
#   nan,
#   nan,
#   31.26946566179252,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2009_000087.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.892389695505386,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Critical'],
#  '2009_000103.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.54786964573989,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2009_000120.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.80608913442844,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2009_000169.jpg': [' person',
#   ' horse',
#   ' car',
#   nan,
#   nan,
#   20.934599857700228,
#   'low',
#   ' car',
#   'Target Present',
#   'Critical'],
#  '2009_000189.jpg': [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   20.934059682149233,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2009_000218.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.096357653476158,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2009_000260.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.088435845702712,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_000466.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.954010715704413,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2009_000488.jpg': [' pottedplant',
#   ' tvmonitor',
#   ' cat',
#   nan,
#   nan,
#   31.67044719842205,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2009_000565.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.530489775112553,
#   'high',
#   ' horse',
#   'Target Present',
#   'Critical'],
#  '2009_000629.jpg': [' tvmonitor',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   34.776343714473143,
#   'high',
#   ' chair',
#   'Target Present',
#   'Critical'],
#  '2009_000760.jpg': [' pottedplant',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   34.177834247690619,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2009_000849.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.965593293603121,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2009_000919.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.253519599924761,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2009_000926.jpg': [' pottedplant',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   35.07912895315846,
#   'high',
#   ' car',
#   'Target Absent',
#   'Critical'],
#  '2009_000937.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.506510529107977,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2009_000939.jpg': [' tvmonitor',
#   ' chair',
#   ' sofa',
#   nan,
#   nan,
#   21.020838805689188,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2009_000996.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.71354671893177,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2009_001042.jpg': [' person',
#   ' train',
#   nan,
#   nan,
#   nan,
#   29.520175506984401,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Critical'],
#  '2009_001279.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.881104569900195,
#   'low',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2009_001312.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.885750448101746,
#   'low',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2009_001321.jpg': [' car',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   37.93755165753997,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_001345.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   28.99541660743073,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_001406.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   19.901616892338367,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2009_001422.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.094574746613134,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2009_001581.jpg': [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   17.45403585170882,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Critical'],
#  '2009_001587.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.603237292930547,
#   'low',
#   ' bird',
#   'Target Present',
#   'Critical'],
#  '2009_001611.jpg': [' person',
#   ' chair',
#   ' dog',
#   nan,
#   nan,
#   31.534770762233748,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2009_001621.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.612033499666907,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2009_001723.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.264337675075122,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Critical'],
#  '2009_001751.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.971879878734466,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2009_001810.jpg': [' person',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   19.615269866751536,
#   'low',
#   ' car',
#   'Target Absent',
#   'Critical'],
#  '2009_001888.jpg': [' pottedplant',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   28.81434208709868,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2009_001902.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.466024664585106,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2009_001927.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.198849698873698,
#   'low',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2009_001975.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.493023991641429,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2009_002001.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   34.544144821561908,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_002120.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.865954112693881,
#   'low',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2009_002123.jpg': [' pottedplant',
#   ' person',
#   nan,
#   nan,
#   nan,
#   19.664476147826182,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2009_002137.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.603518928106915,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2009_002325.jpg': [' sofa',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   19.836491630222174,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2009_002374.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.138559565527519,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2009_002414.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.742786682331467,
#   'high',
#   ' cat',
#   'Target Absent',
#   'Normal'],
#  '2009_002465.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.840306010235047,
#   'low',
#   ' bird',
#   'Target Present',
#   'Critical'],
#  '2009_002521.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.832521553254701,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2009_002567.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.935773517813168,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2009_002594.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.096237359535362,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2009_002634.jpg': [' person',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   29.98976583618353,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2009_002749.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.96364307633711,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2009_002817.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.54050687002545,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2009_002820.jpg': [' tvmonitor',
#   ' bird',
#   nan,
#   nan,
#   nan,
#   15.427788040321774,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2009_002888.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.000361854332464,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_003084.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.074715872568312,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2009_003338.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   30.130898028557787,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2009_003530.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   20.529451477248333,
#   'low',
#   ' horse',
#   'Target Present',
#   'Critical'],
#  '2009_003646.jpg': [' tvmonitor',
#   ' person',
#   ' bicycle',
#   ' sofa',
#   nan,
#   38.218905954735177,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Critical'],
#  '2009_003705.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   29.547306113597852,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_003734.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   29.109546590342212,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2009_003786.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.613483339702352,
#   'high',
#   ' dog',
#   'Target Present',
#   'Critical'],
#  '2009_003795.jpg': [' person',
#   ' diningtable',
#   ' bottle',
#   ' sofa',
#   nan,
#   38.918529803486521,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2009_003899.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.0846265009977,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Critical'],
#  '2009_003950.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   18.818576466753129,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2009_004044.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.145729614391094,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2009_004076.jpg': [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   15.553393150912814,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2009_004092.jpg': [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   30.45665321649669,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2009_004094.jpg': [' person',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   37.438249820139532,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2009_004129.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   11.459232377151848,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2009_004154.jpg': [' person',
#   ' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   29.622914279842281,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2009_004179.jpg': [' person',
#   ' chair',
#   ' dog',
#   ' car',
#   nan,
#   31.410853470588716,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2009_004199.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.55732937443792,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2009_004263.jpg': [' pottedplant',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   21.053503723789198,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2009_004414.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.972960084007049,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_004582.jpg': [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   20.382684879012675,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Critical'],
#  '2009_004614.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.797485292367842,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2009_004620.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.412798785536999,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2009_004737.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.985442334643722,
#   'low',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2009_004780.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.019585017762431,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2009_004794.jpg': [' pottedplant',
#   ' person',
#   ' bottle',
#   ' diningtable',
#   nan,
#   36.665582819269645,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2009_004841.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.687437917190536,
#   'high',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2009_004888.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   16.651242460530831,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2009_004897.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.40072940696016,
#   'low',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2009_004984.jpg': [' bicycle',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   18.893798014446215,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2009_005008.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.770158360863313,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2009_005044.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.713624833374665,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2009_005075.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.272204751551552,
#   'low',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2009_005133.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.270464835358208,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2009_005190.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.955144113025266,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Critical'],
#  '2009_005257.jpg': [' person',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   32.632138351243327,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2010_000073.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.42947512964443,
#   'low',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2010_000074.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   32.142427134910967,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_000109.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.194101616126162,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2010_000132.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.906276626032106,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2010_000198.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.882931151862195,
#   'low',
#   ' car',
#   'Target Present',
#   'Critical'],
#  '2010_000299.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.706122139777047,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2010_000389.jpg': [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   17.828359021050446,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2010_000426.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.883134744539575,
#   'low',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2010_000536.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.54166437440535,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2010_000705.jpg': [' tvmonitor',
#   ' chair',
#   nan,
#   nan,
#   nan,
#   31.685316062100558,
#   'high',
#   ' chair',
#   'Target Present',
#   'Critical'],
#  '2010_000750.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   11.902212339033813,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2010_000805.jpg': [' dog',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   18.86070334209068,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Critical'],
#  '2010_000836.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.711202801099512,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2010_000838.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   20.405728055332247,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2010_000874.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.572069058291632,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2010_001036.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   19.194815950035924,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2010_001074.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.697080535123286,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_001211.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.705926263540768,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_001220.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.327134032396973,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2010_001270.jpg': [' person',
#   ' tvmonitor',
#   nan,
#   nan,
#   nan,
#   34.992247329843039,
#   'high',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2010_001271.jpg': [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   20.735145690609489,
#   'low',
#   ' chair',
#   'Target Present',
# ...
#  '2010_002654.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.428016033505308,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_002661.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.880571606430006,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2010_002702.jpg': [' person',
#   ' boat',
#   ' car',
#   nan,
#   nan,
#   35.704708934850657,
#   'high',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2010_002775.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.77784058169977,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_002789.jpg': [' sofa',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   33.208929252766531,
#   'high',
#   ' cat',
#   'Target Present',
#   'Critical'],
#  '2010_002958.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.213501814359315,
#   'low',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2010_003101.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.252734908007358,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2010_003232.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.667073376240573,
#   'high',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2010_003280.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   20.306835318139004,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2010_003287.jpg': [' tvmonitor',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   20.155193047230767,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2010_003297.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   31.969634324354409,
#   'high',
#   ' horse',
#   'Target Present',
#   'Critical'],
#  '2010_003329.jpg': [' bottle',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.965775321926717,
#   'low',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2010_003374.jpg': [' person',
#   ' chair',
#   ' diningtable',
#   ' bottle',
#   nan,
#   41.543326418283335,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2010_003400.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   11.740304537002435,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2010_003419.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.667065204437929,
#   'high',
#   ' bird',
#   'Target Present',
#   'Critical'],
#  '2010_003520.jpg': [' sofa',
#   ' chair',
#   ' diningtable',
#   nan,
#   nan,
#   35.492312020496826,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2010_003579.jpg': [' chair',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   29.798629151951733,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Critical'],
#  '2010_003588.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   19.052504894146868,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_003696.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   12.030650961784945,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2010_003724.jpg': [' person',
#   ' bird',
#   nan,
#   nan,
#   nan,
#   29.657389969329227,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2010_003746.jpg': [' car',
#   ' dog',
#   ' person',
#   nan,
#   nan,
#   21.020159211351668,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2010_003861.jpg': [' pottedplant',
#   ' person',
#   ' chair',
#   ' sofa',
#   ' cat',
#   29.727129597298969,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2010_003864.jpg': [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' diningtable',
#   ' tvmonitor',
#   31.00753792387394,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2010_003911.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.084302537016953,
#   'low',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2010_004014.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.597981681742631,
#   'low',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2010_004145.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.590456430582357,
#   'low',
#   ' horse',
#   'Target Present',
#   'Critical'],
#  '2010_004423.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.739677956098852,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2010_004425.jpg': [' sofa',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   18.288477341906038,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2010_004447.jpg': [' person',
#   ' bottle',
#   ' sofa',
#   nan,
#   nan,
#   33.561185784733894,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Critical'],
#  '2010_004448.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.26346771187163,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Critical'],
#  '2010_004461.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.712155258408515,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2010_004542.jpg': [' person',
#   ' horse',
#   nan,
#   nan,
#   nan,
#   33.854821153874802,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2010_004543.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   35.339849208358679,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2010_004662.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   21.198620417532712,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2010_004683.jpg': [' pottedplant',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   28.663633475174361,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2010_004733.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   15.631298800361767,
#   'low',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2010_004779.jpg': [' person',
#   ' train',
#   nan,
#   nan,
#   nan,
#   30.539116654988586,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2010_004791.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.120761243201123,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2010_005016.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.126154609684278,
#   'low',
#   ' bird',
#   'Target Present',
#   'Critical'],
#  '2010_005101.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   13.350033322032775,
#   'low',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2010_005106.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.242937209299559,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2010_005170.jpg': [' person',
#   ' chair',
#   ' diningtable',
#   ' sofa',
#   nan,
#   30.916466766406522,
#   'high',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2010_005236.jpg': [' car',
#   ' person',
#   nan,
#   nan,
#   nan,
#   21.093164998815773,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2010_005239.jpg': [' tvmonitor',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   33.319550308764342,
#   'high',
#   ' cat',
#   'Target Present',
#   'Critical'],
#  '2010_005270.jpg': [' person',
#   ' horse',
#   ' dog',
#   nan,
#   nan,
#   31.37245999871385,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_005279.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.467308574532574,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Critical'],
#  '2010_005317.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.663562286715823,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2010_005318.jpg': [' car',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   29.982067460147125,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2010_005437.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.487166726481941,
#   'low',
#   ' car',
#   'Target Present',
#   'Critical'],
#  '2010_005595.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.694123468445483,
#   'high',
#   ' horse',
#   'Target Present',
#   'Normal'],
#  '2010_005606.jpg': [' person',
#   ' sofa',
#   ' cat',
#   nan,
#   nan,
#   29.514189787401428,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Critical'],
#  '2010_005608.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.272654602537909,
#   'high',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2010_005628.jpg': [' pottedplant',
#   ' person',
#   ' chair',
#   ' dog',
#   nan,
#   34.099790178372324,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2010_005669.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   33.960677529937648,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2010_005705.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.07547411972709,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2010_005718.jpg': [' car',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   32.224520766602424,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Critical'],
#  '2010_005733.jpg': [' person',
#   ' horse',
#   ' car',
#   nan,
#   nan,
#   29.432586303244623,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Normal'],
#  '2010_005780.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.846336579249186,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2010_005785.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   16.197035825449316,
#   'low',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2010_005868.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   20.696179698196744,
#   'low',
#   ' car',
#   'Target Present',
#   'Normal'],
#  '2010_005921.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   28.810222255541373,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2011_000009.jpg': [' tvmonitor',
#   ' chair',
#   ' bottle',
#   ' person',
#   nan,
#   35.250282891473262,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2011_000036.jpg': [' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   nan,
#   nan,
#   34.133889572243696,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2011_000173.jpg': [' sofa',
#   nan,
#   nan,
#   nan,
#   nan,
#   30.606579039143625,
#   'high',
#   ' boat',
#   'Target Absent',
#   'Normal'],
#  '2011_000278.jpg': [' person',
#   ' boat',
#   ' car',
#   nan,
#   nan,
#   35.334645975604097,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2011_000293.jpg': [' car',
#   nan,
#   nan,
#   nan,
#   nan,
#   9.1563902861608657,
#   'low',
#   ' car',
#   'Target Present',
#   'Critical'],
#  '2011_000379.jpg': [' sofa',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   21.054250295020399,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2011_000530.jpg': [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' diningtable',
#   nan,
#   29.806819625699735,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2011_000548.jpg': [' bird',
#   ' cow',
#   nan,
#   nan,
#   nan,
#   30.96122100405093,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2011_000661.jpg': [' chair',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   19.7971714164348,
#   'low',
#   ' cat',
#   'Target Present',
#   'Normal'],
#  '2011_000689.jpg': [' sofa',
#   ' chair',
#   ' person',
#   nan,
#   nan,
#   31.483858198815106,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2011_000828.jpg': [' sofa',
#   ' bottle',
#   ' person',
#   nan,
#   nan,
#   29.479716970441856,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2011_001001.jpg': [' person',
#   ' bird',
#   ' boat',
#   nan,
#   nan,
#   31.913409738647122,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2011_001005.jpg': [' pottedplant',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   18.96772267222304,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2011_001025.jpg': [' pottedplant',
#   ' person',
#   ' bicycle',
#   ' car',
#   nan,
#   33.367152749801264,
#   'high',
#   ' sofa',
#   'Target Absent',
#   'Normal'],
#  '2011_001097.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   33.035936302633694,
#   'high',
#   ' pottedplant',
#   'Target Absent',
#   'Normal'],
#  '2011_001116.jpg': [' person',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   29.77854418273715,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2011_001139.jpg': [' chair',
#   ' bird',
#   ' diningtable',
#   nan,
#   nan,
#   29.361755720318889,
#   'high',
#   ' bird',
#   'Target Present',
#   'Critical'],
#  '2011_001173.jpg': [' sofa',
#   ' cat',
#   nan,
#   nan,
#   nan,
#   20.434103820691529,
#   'low',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2011_001283.jpg': [' sofa',
#   ' person',
#   nan,
#   nan,
#   nan,
#   32.359021546110327,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2011_001320.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.619907721675858,
#   'low',
#   ' person',
#   'Target Absent',
#   'Normal'],
#  '2011_001382.jpg': [' pottedplant',
#   ' person',
#   ' diningtable',
#   ' bottle',
#   nan,
#   28.939513311425664,
#   'high',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2011_001503.jpg': [' person',
#   ' sofa',
#   nan,
#   nan,
#   nan,
#   31.068506377399114,
#   'high',
#   ' sofa',
#   'Target Present',
#   'Normal'],
#  '2011_001566.jpg': [' pottedplant',
#   ' chair',
#   ' bicycle',
#   nan,
#   nan,
#   34.252594206283753,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2011_001591.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   17.698167132036819,
#   'low',
#   ' person',
#   'Target Present',
#   'Normal'],
#  '2011_001605.jpg': [' pottedplant',
#   ' person',
#   ' motorbike',
#   nan,
#   nan,
#   34.416005433315377,
#   'high',
#   ' horse',
#   'Target Absent',
#   'Normal'],
#  '2011_001613.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   17.516941478695085,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2011_001655.jpg': [' person',
#   ' train',
#   nan,
#   nan,
#   nan,
#   33.249285132898933,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2011_001656.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.156547420300022,
#   'low',
#   ' boat',
#   'Target Absent',
#   'Critical'],
#  '2011_001779.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.684730992524468,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal'],
#  '2011_001800.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.95304328989037,
#   'high',
#   ' dog',
#   'Target Absent',
#   'Normal'],
#  '2011_001862.jpg': [' pottedplant',
#   ' sofa',
#   ' chair',
#   ' dog',
#   ' diningtable',
#   32.89256213346399,
#   'high',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2011_001880.jpg': [' aeroplane',
#   nan,
#   nan,
#   nan,
#   nan,
#   32.202764020748532,
#   'high',
#   ' aeroplane',
#   'Target Present',
#   'Normal'],
#  '2011_001886.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.685752299806754,
#   'low',
#   ' boat',
#   'Target Present',
#   'Critical'],
#  '2011_001902.jpg': [' bird',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.504215173999519,
#   'low',
#   ' bird',
#   'Target Present',
#   'Normal'],
#  '2011_001930.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   18.813366535610786,
#   'low',
#   ' horse',
#   'Target Absent',
#   'Critical'],
#  '2011_001972.jpg': [' chair',
#   nan,
#   nan,
#   nan,
#   nan,
#   10.59386678794856,
#   'low',
#   ' bottle',
#   'Target Absent',
#   'Critical'],
#  '2011_001991.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   34.047146905280911,
#   'high',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2011_002050.jpg': [' boat',
#   nan,
#   nan,
#   nan,
#   nan,
#   17.331558080669492,
#   'low',
#   ' dog',
#   'Target Absent',
#   'Critical'],
#  '2011_002098.jpg': [' dog',
#   ' bottle',
#   nan,
#   nan,
#   nan,
#   41.997144703218737,
#   'high',
#   ' bottle',
#   'Target Present',
#   'Normal'],
#  '2011_002193.jpg': [' person',
#   ' aeroplane',
#   nan,
#   nan,
#   nan,
#   30.182885716527558,
#   'high',
#   ' car',
#   'Target Absent',
#   'Normal'],
#  '2011_002239.jpg': [' person',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   31.319653473122486,
#   'high',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2011_002241.jpg': [' chair',
#   ' diningtable',
#   nan,
#   nan,
#   nan,
#   18.117802795100609,
#   'low',
#   ' chair',
#   'Target Present',
#   'Normal'],
#  '2011_002453.jpg': [' pottedplant',
#   nan,
#   nan,
#   nan,
#   nan,
#   19.24976137409617,
#   'low',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2011_002558.jpg': [' person',
#   ' boat',
#   nan,
#   nan,
#   nan,
#   16.146154777978307,
#   'low',
#   ' boat',
#   'Target Present',
#   'Normal'],
#  '2011_002624.jpg': [' person',
#   nan,
#   nan,
#   nan,
#   nan,
#   31.033903320780912,
#   'high',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2011_002631.jpg': [' cat',
#   nan,
#   nan,
#   nan,
#   nan,
#   29.37680987232249,
#   'high',
#   ' aeroplane',
#   'Target Absent',
#   'Normal'],
#  '2011_002760.jpg': [' person',
#   ' motorbike',
#   nan,
#   nan,
#   nan,
#   29.2374513625536,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Critical'],
#  '2011_002766.jpg': [' sofa',
#   ' dog',
#   nan,
#   nan,
#   nan,
#   19.88562665685453,
#   'low',
#   ' dog',
#   'Target Present',
#   'Normal'],
#  '2011_002810.jpg': [' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   ' sofa',
#   nan,
#   35.636604201684968,
#   'high',
#   ' pottedplant',
#   'Target Present',
#   'Normal'],
#  '2011_002814.jpg': [' sofa',
#   ' bottle',
#   ' pottedplant',
#   ' tvmonitor',
#   ' chair',
#   33.937775623898794,
#   'high',
#   ' bird',
#   'Target Absent',
#   'Critical'],
#  '2011_003098.jpg': [' dog',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.526602394583092,
#   'low',
#   ' bottle',
#   'Target Absent',
#   'Normal'],
#  '2011_003244.jpg': [' horse',
#   nan,
#   nan,
#   nan,
#   nan,
#   14.779476597381954,
#   'low',
#   ' chair',
#   'Target Absent',
#   'Normal']}

# %%
# DEFINING BLOCKS
low_present_normal = []
low_present_critical = []
low_absent_normal = []
low_absent_critical = []
high_present_normal = []
high_present_critical = []
high_absent_normal = []
high_absent_critical = []

list_dict = {}
list_dict['low_present_normal'] = low_present_normal
list_dict['low_present_critical'] = low_present_critical
list_dict['low_absent_normal'] = low_absent_normal
list_dict['low_absent_critical'] = low_absent_critical
list_dict['high_present_normal'] = high_present_normal
list_dict['high_present_critical'] = high_present_critical
list_dict['high_absent_normal'] = high_absent_normal
list_dict['high_absent_critical'] = high_absent_critical

def block(load,present_absent, normal_critical,target_list_name):
    target_list = list_dict[target_list_name]
    for each in exp_dict:
        if load in exp_dict[each] and present_absent in exp_dict[each] and normal_critical in exp_dict[each]:
            target_list.append(each)

block('low','Target Present','Normal','low_present_normal')  
block('low','Target Absent','Normal','low_absent_normal')
block('low','Target Present','Critical','low_present_critical')  
block('low','Target Absent','Critical','low_absent_critical')
block('high','Target Present','Normal','high_present_normal')
block('high','Target Present','Critical','high_present_critical')
block('high','Target Absent','Normal','high_absent_normal')
block('high','Target Absent','Critical','high_absent_critical')
print len(low_present_normal), len(low_absent_normal), len(low_present_critical), len(low_absent_critical)
print len(high_present_normal), len(high_absent_normal), len(high_present_critical), len(high_absent_critical)
#--------------------

block_one = []
block_two = []
block_three = []
block_four = []

intermediate = []
intermediate.append(np.random.choice(low_present_normal, 50, replace= False))
intermediate.append(np.random.choice(low_present_critical, 10, replace= False))
intermediate.append(np.random.choice(low_absent_normal, 50, replace= False))
intermediate.append(np.random.choice(low_absent_critical, 10, replace= False))
for each in intermediate:
    block_one.append(each)
print len(block_one), block_one
# Out:
# 100 100 20 20
# 100 100 20 20
# 4 [array(['2010_005101.jpg', '2008_004814.jpg', '2008_006072.jpg',
#        '2009_000939.jpg', '2011_002766.jpg', '2008_002410.jpg',
#        '2008_007733.jpg', '2010_000750.jpg', '2008_008533.jpg',
#        '2008_000398.jpg', '2009_004076.jpg', '2008_003170.jpg',
#        '2010_001448.jpg', '2008_003868.jpg', '2008_008211.jpg',
#        '2008_003048.jpg', '2009_000189.jpg', '2008_002899.jpg',
#        '2008_004907.jpg', '2011_000379.jpg', '2008_004270.jpg',
#        '2011_000661.jpg', '2008_006837.jpg', '2008_000177.jpg',
#        '2008_004868.jpg', '2008_005853.jpg', '2008_003369.jpg',
#        '2008_007816.jpg', '2008_007973.jpg', '2009_004129.jpg',
#        '2009_004620.jpg', '2009_002594.jpg', '2009_000260.jpg',
#        '2011_001613.jpg', '2008_006546.jpg', '2008_000142.jpg',
#        '2010_002393.jpg', '2009_004897.jpg', '2008_000734.jpg',
#        '2008_002379.jpg', '2008_002666.jpg', '2010_001271.jpg',
#        '2008_000064.jpg', '2010_004014.jpg', '2009_001406.jpg',
#        '2010_005868.jpg', '2011_002241.jpg', '2009_000937.jpg',
#        '2011_001005.jpg', '2008_000501.jpg'],
#       dtype='|S15'), array(['2009_002465.jpg', '2009_000169.jpg', '2009_001587.jpg',
#        '2009_003530.jpg', '2008_006119.jpg', '2009_005190.jpg',
#        '2008_000033.jpg', '2010_002286.jpg', '2011_000293.jpg',
#        '2010_005437.jpg'],
#       dtype='|S15'), array(['2008_005396.jpg', '2008_000189.jpg', '2010_004461.jpg',
#        '2010_005236.jpg', '2009_002325.jpg', '2008_002442.jpg',
#        '2011_001779.jpg', '2008_006470.jpg', '2008_006092.jpg',
#        '2008_006921.jpg', '2009_001975.jpg', '2010_003280.jpg',
#        '2009_002137.jpg', '2008_000112.jpg', '2008_001503.jpg',
#        '2008_000533.jpg', '2009_000919.jpg', '2011_003098.jpg',
#        '2008_002487.jpg', '2010_001220.jpg', '2011_003244.jpg',
#        '2010_003746.jpg', '2008_004269.jpg', '2009_001312.jpg',
#        '2009_001902.jpg', '2008_001188.jpg', '2008_005167.jpg',
#        '2008_000089.jpg', '2008_003766.jpg', '2008_006276.jpg',
#        '2008_000666.jpg', '2010_003400.jpg', '2009_005044.jpg',
#        '2009_001422.jpg', '2009_002521.jpg', '2008_003104.jpg',
#        '2010_000299.jpg', '2008_008083.jpg', '2008_005869.jpg',
#        '2010_001638.jpg', '2008_007511.jpg', '2009_004044.jpg',
#        '2010_004733.jpg', '2009_002749.jpg', '2008_001318.jpg',
#        '2008_000839.jpg', '2008_000076.jpg', '2008_004171.jpg',
#        '2009_005008.jpg', '2010_000838.jpg'],
#       dtype='|S15'), array(['2008_004933.jpg', '2011_001972.jpg', '2008_002866.jpg',
#        '2008_003587.jpg', '2008_005522.jpg', '2008_001714.jpg',
#        '2010_004448.jpg', '2010_005279.jpg', '2008_004175.jpg',
#        '2008_000721.jpg'],
#       dtype='|S15')]
